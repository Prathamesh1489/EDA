# %% [markdown]
# # EDA-Exploratory Data Analysis

# %% [markdown]
# # 1) Descriptive statistics:

# %%
import pandas as pd
data=pd.read_csv('1.csv')

# %%
data
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
data['over'].describe()
# Out:
# count    193468.000000
# mean          9.177027
# std           5.676848
# min           0.000000
# 25%           4.000000
# 50%           9.000000
# 75%          14.000000
# max          19.000000
# Name: over, dtype: float64

# %%
data['over'].value_counts()
# Out:
# 1     10255
# 0     10254
# 2     10155
# 3     10115
# 4     10092
# 5     10067
# 6     10021
# 7      9993
# 8      9964
# 9      9920
# 10     9864
# 11     9833
# 12     9806
# 13     9712
# 14     9638
# 15     9477
# 16     9358
# 17     9086
# 18     8531
# 19     7327
# Name: over, dtype: int64

# %%
c

# %%
sns.scatterplot( y=data["over"], x=data["batsman_runs"] );
plt.show()

# %% [markdown]
# # 2) GroupBy:

# %%
data.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
data_test=data[['batsman_runs','extra_runs']]
data_test
# Out:
#         batsman_runs  extra_runs
# 0                  1           0
# 1                  1           0
# 2                  0           0
# 3                  1           0
# 4                  1           0
# ...              ...         ...
# 193463             0           0
# 193464             1           0
# 193465             0           1
# 193466             1           0
# 193467             1           0
#
# [193468 rows x 2 columns]

# %%
data_group=data.groupby('batsman').groups
data_group
# Out:
# {'A Ashish Reddy': [67684, 67685, 67686, 67687, 67689, 67693, 67694, 67695, 67696, 67697, 69281, 69286, 69287, 70847, 70849, 70850, 70852, 70853, 70854, 70856, 70857, 74398, 74399, 74400, 74401, 75077, 75078, 75079, 75081, 75083, 76912, 76914, 76915, 77026, 77832, 77834, 78003, 78004, 78006, 78008, 78009, 78011, 78012, 78018, 78020, 78021, 79262, 79264, 79265, 79266, 79267, 79269, 79270, 79271, 79272, 80013, 80016, 80017, 80019, 80020, 81225, 81229, 81231, 81232, 81234, 81235, 81359, 81360, 81361, 81363, 81366, 81367, 81369, 81370, 81373, 82067, 82071, 82073, 82075, 82076, 82077, 82081, 84103, 84104, 84105, 84108, 84109, 84110, 84111, 84114, 84117, 84118, 84123, 84124, 84125, 84126, 84127, 84128, 84582, 84583, ...], 'A Chandila': [74235, 82421, 82423, 82424, 82434, 82435, 82436], 'A Chopra': [6615, 6616, 6618, 6624, 6629, 7588, 7589, 7590, 7591, 7595, 7596, 7605, 7616, 7617, 7618, 7624, 7628, 7629, 7630, 7631, 7633, 7634, 7635, 7636, 7637, 7639, 7640, 7641, 7642, 7644, 8301, 8302, 83
# ...

# %%
data_pivot=pd.pivot_table(data, index =['batsman','batsman_runs'])
data_pivot
# Out:
#                                  ball  extra_runs             id    inning  \
# batsman        batsman_runs
# A Ashish Reddy 0             3.622951    0.131148  699598.721311  1.475410
#                1             3.783133    0.000000  705656.108434  1.361446
#                2             3.000000    0.000000  676760.250000  1.350000
#                3             6.000000    0.000000  598030.000000  1.000000
#                4             3.500000    0.000000  680022.437500  1.625000
# ...                               ...         ...            ...       ...
# Z Khan         0             3.864865    0.040541  595738.635135  1.608108
#                1             3.510638    0.021277  508546.574468  1.680851
#                2             4.000000    0.000000  460908.285714  1.571429
#                4             3.454545    0.000000  466647.545455  1.363636
#                6             4.000000    0.000000  574211.000000  1.000000
#
# ...

# %%
sns.heatmap(data_pivot,annot=True,cmap='coolwarm');

# %%
plt.pcolor(data_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# # 3) Anova:

# %%
data_anova=data[['batsman_runs','extra_runs']]
data_anova
# Out:
#         batsman_runs  extra_runs
# 0                  1           0
# 1                  1           0
# 2                  0           0
# 3                  1           0
# 4                  1           0
# ...              ...         ...
# 193463             0           0
# 193464             1           0
# 193465             0           1
# 193466             1           0
# 193467             1           0
#
# [193468 rows x 2 columns]

# %%
grouped_anova=data_anova.groupby(['batsman_runs'])

# %% [markdown]
# # 4) Correlation

# %%
sns.regplot(x='batsman_runs',y='extra_runs',data=data_anova)
plt.ylim(0,)
# Out:
# (0.0, 7.3538722299307695)
